# %% [markdown]
# # ADNI Data Exploration, Wrangling, and Feature Engineering/Selection
#
# **Deliverable:** This notebook is a structured template. Fill in all **TODO** sections with your work, results, and explanations.
#
# **Dataset:** ADNI tabular dataset (e.g., ADNIMERGE or instructor-provided CSV)
#
# **Author:** <Your Name>
# **Course:** <Course Code / Title>
# **Date:** <YYYY-MM-DD>

# %% [markdown]
# ## 1. Setup
#
# This section standardizes imports, configuration, and reproducibility settings.

# %% [markdown]
# ## 2. Load Data
#
# Load the ADNI dataset. Clearly state which file(s) you used.

# %% [markdown]
# ### 2.1 Data Dictionary / Column Notes (Required)
#
# - **Unit of observation:** (e.g., subject visit)
# - **Key identifiers present:** (e.g., RID, PTID)
# - **Any known target/label:** (optional unless required by instructor)
#
# **TODO:** Add notes about important columns (clinical context, measurement units, etc.).

# %% [markdown]
# ## 3. Initial Audit
#
# Perform a quick audit: types, duplicates, missingness, and descriptive statistics.

# %% [markdown]
# ### 3.1 Missingness Summary
# Compute missing values per column (count and percentage) and visualize missingness.

# %% [markdown]
# ## 4. Data Cleaning
#
# This section includes:
# 1) Missing data handling (impute vs drop)
# 2) Incorrect data detection and correction
# 3) Unnecessary feature removal

# %% [markdown]
# ### 4.1 Missing Data Handling (Required)
#
# **Instructions:**
# - Choose at least **three** columns with missing values.
# - Decide whether to impute or drop (rows/columns), and justify your decision.
#
# **TODO:** Document your decisions in markdown and implement your approach below.

# %% [markdown]
# ### 4.2 Incorrect Data (Required)
#
# Identify at least **two** incorrect/inconsistent data issues, for example:
# - Impossible ranges (e.g., negative age)
# - Inconsistent categorical labels (e.g., 'M', 'Male', 'male')
# - Outliers likely due to data-entry errors
#
# **TODO:** Provide evidence before/after and justify your corrective action.

# %% [markdown]
# ### 4.3 Unnecessary Data (Required)
#
# Identify at least **two** unnecessary features and justify removal, such as:
# - Identifiers not useful for modeling (RID, PTID, etc.)
# - Duplicated/redundant columns
# - Near-zero variance features
# - Leakage features (if you define a target)
#
# **TODO:** List and drop unnecessary features with clear reasoning.

# %% [markdown]
# ## 5. Feature Engineering
#
# You must select **three relevant features** and justify why they are meaningful for downstream ML.
# Then address encoding and scaling requirements.

# %% [markdown]
# ### 5.1 Select Three Relevant Features (Required)
#
# **TODO:** Choose three features (columns) and justify them in markdown.
#
# Then set:
# - `selected_features` = list of three feature names
# - Optionally, define `target_col` if you want to color plots by diagnosis (e.g., DX)

# %% [markdown]
# ### 5.2 Encoding (Required)
#
# Determine if any retained features are categorical and require encoding.
# Explain why encoding is (or is not) necessary.
#
# **TODO:** Identify categorical columns and apply encoding where appropriate.

# %% [markdown]
# ### 5.3 Scaling (Required)
#
# Decide whether scaling is necessary and which method to use in your main pipeline:
# - Standardization (z-score) OR
# - Normalization (min-max)
#
# Additionally, you must compare raw vs normalized vs standardized for **50 sampled rows** using your **three selected features**.

# %% [markdown]
# ### 5.4 Build a Preprocessing Pipeline (Recommended)
#
# Create a preprocessing pipeline that:
# - imputes missing values (if any remain),
# - encodes selected categorical features (if used),
# - scales numeric features using your chosen method.
#
# **TODO:** Configure the pipeline to match your earlier decisions and produce a final feature matrix `X`.

# %% [markdown]
# ## 6. Dimensionality Reduction
#
# This section includes:
# - Brief curse-of-dimensionality reasoning (in markdown)
# - Implementation of one dimensionality reduction method (PCA recommended)
# - 2D visualization of the reduced embedding

# %% [markdown]
# ### 6.1 Curse of Dimensionality (Required)
#
# **TODO (Markdown):**
# 1. Could this dataset suffer from curse of dimensionality? Why? Use dataset-specific evidence (samples vs features).
# 2. Provide at least two mitigation strategies.
# 3. Explain why dimensionality reduction is suitable here.

# %% [markdown]
# ### 6.2 Implement Dimensionality Reduction (Required)
#
# Implement one method (PCA / UMAP / t-SNE). PCA is recommended as a baseline.
#
# Minimum requirements:
# - Reduce to 2 components for visualization
# - Also test another setting (e.g., 5 or 10 components OR variance-threshold approach)
# - Provide at least one plot

# %% [markdown]
# ## 7. Conclusion
#
# **TODO (Markdown):** Summarize:
# - Key cleaning decisions (impute vs drop, incorrect data fixes, unnecessary feature removal)
# - Feature engineering decisions (encoding, scaling and why)
# - Dimensionality reduction results (what you learned from PCA/other method)
# - Limitations and next steps
